# %%
library(magick)
library(ggplot2)
library(gridExtra)
library(grid)
library(pdftools)
library(cowplot)
library(ggplotify )
library("ggpubr")
theme_set(
  theme_bw() +
    theme(legend.position = "top")
  )

# %% [markdown]
# Fig 2

# %%
p1 <- image_read_pdf("../../results/fig/allenmouseheatmap_GMM.pdf")
p2 <- image_read_pdf("../../results/fig/allenmousemds_GMM_sqrt.pdf")
p1 <- as.grob(p1)
p2 <- as.grob(p2)

# %%
grid.arrange(p1, p2, ncol = 2)
# Out:
# plot without title

# %%
pdf("../../results/fig/fig2.pdf", width = 6, height = 3.5)


plot_grid(p1,p2,ncol = 2, labels=c(LETTERS[1], LETTERS[2]), rel_widths = c(3,2))

dev.off()
# Out:
# png
#   2

# %%
p1 <- image_read_pdf("../../results/fig/rash_s12_heatmap_GMM.pdf")
p2 <- image_read_pdf("../../results/fig/rash_s12_mds_GMM_sqrt.pdf")
p1 <- as.grob(p1)
p2 <- as.grob(p2)

# %%
grid.arrange(p1, p2, ncol = 2)
# Out:
# plot without title

# %%
pdf("../../results/fig/fig3.pdf", width = 6, height = 3)


plot_grid(p1,p2,ncol = 2, labels=c(LETTERS[1], LETTERS[2]), rel_widths = c(3,2))

dev.off()
# Out:
# png
#   2

# %% [markdown]
# fig 4

# %%
p1 <- image_read_pdf("../../results/fig/COVID_lung_mds_GMM_sqrt.pdf")
p2 <- image_read_pdf("../../results/fig/pelka_GMM_mds_sqrt.pdf")
p1 <- as.grob(p1)
p2 <- as.grob(p2)

# %%
grid.arrange(p1, p2, ncol = 2)
# Out:
# plot without title

# %%
pdf("../../results/fig/fig4.pdf", width = 6, height = 3)


plot_grid(p1,p2,ncol = 2, labels=c(LETTERS[1], LETTERS[2]))

dev.off()
# Out:
# png
#   2

# %% [markdown]
# fig 5

# %%
p1 <- image_read_pdf("../../results/supplement/boxplot_cluster_gmmpca.pdf")
p2 <- image_read_pdf("../../results/supplement/boxplot_lfcpde_gmmpca.pdf")
p3 <- image_read_pdf("../../results/supplement/boxplot_sd_w_gmmpca.pdf")
p4 <- image_read_pdf("../../results/supplement/boxplot_alpha_w_gmmpca.pdf")
p1 <- as.grob(p1)
p2 <- as.grob(p2)
p3 <- as.grob(p3)
p4 <- as.grob(p4)

# %%
plot_grid(p1,p2,p3,p4,ncol = 2, labels=c(LETTERS[1:4]))
# Out:
# plot without title

# %%
pdf("../../results/fig/fig5.pdf", width = 6, height = 5.5)

plot_grid(p1,p2,p3,p4,ncol = 2, labels=c(LETTERS[1:4]))

dev.off()
# Out:
# png
#   2

# %% [markdown]
# Fig 6

# %%
p1 <- image_read_pdf("../../results/fig/cluster_GMMPCA.pdf")
p2 <- image_read_pdf("../../results/fig/lfc_pde.pdf")
p3 <- image_read_pdf("../../results/fig/omega_k.pdf")
p1 <- as.grob(p1)
p2 <- as.grob(p2)
p3 <- as.grob(p3)

# %%
plot_grid(
    plot_grid(NULL, p1, NULL, nrow = 1, rel_widths = c(0, 1, 0), labels = LETTERS[1]),
  plot_grid(p2, p3, nrow = 1, ncol = 2,labels=c(LETTERS[2:3])),
  nrow = 2
)
# Out:
# plot without title

# %%
pdf("../../results/fig/fig6.pdf", width = 6, height = 6)

plot_grid(
    plot_grid(NULL, p1, NULL, nrow = 1, rel_widths = c(0, 1, 0), labels = LETTERS[1]),
  plot_grid(p2, p3, nrow = 1, ncol = 2,labels=c(LETTERS[2:3])),
  nrow = 2
)

dev.off()
# Out:
# png
#   2

# %% [markdown]
# fig 7

# %%
p1 <- image_read_pdf("../../results/fig/covid143allGMMPCA.pdf")
p2 <- image_read_pdf("../../results/fig/covid143_legend.pdf")
p3 <- image_read_pdf("../../results/fig/covid143GMMpca.pdf")
p1 <- as.grob(p1)
p2 <- as.grob(p2)
p3 <- as.grob(p3)

# %%
plot_grid(p1,p2,p3,ncol = 3, labels=c(LETTERS[1],"", LETTERS[2]), rel_widths = c(2.5,1,2.5))
# Out:
# plot without title

# %%
pdf("../../results/fig/fig7.pdf", width = 6, height = 3)

plot_grid(p1,p2,p3,ncol = 3, labels=c(LETTERS[1],"", LETTERS[2]), rel_widths = c(2.5,1,2.5))

dev.off()
# Out:
# png
#   2

# %% [markdown]
# fig 8

# %%
p1 <- image_read_pdf("../../results/fig/fabrelung_GMMpca_sqrt.pdf")
p2 <- image_read_pdf("../../results/fig/image/fig/fabrelung_GMMharbat_sqrt.pdf")
p3 <- image_read_pdf("../../results/fig/fabrelung_legend_update.pdf")
p4 <- image_read_pdf("../../results/fig/fabreLung_ans.pdf")
p5 <- image_read_pdf("../../results/fig/fabreLung_ss.pdf")
p1 <- as.grob(p1)
p2 <- as.grob(p2)
p3 <- as.grob(p3)
p4 <- as.grob(p4)
p5 <- as.grob(p5)

# %%
plot_grid(
      plot_grid(p1, p2, nrow = 1, ncol = 2,labels=c(LETTERS[1:2])),
    plot_grid(NULL, p3, NULL, nrow = 1, rel_widths = c(0.3, 1, 0.3)),
  plot_grid(p4, p5, nrow = 1, ncol = 2,labels=c(LETTERS[3:4])),
  nrow = 3, rel_heights = c(1,0.5,1)
)
# Out:
# plot without title

# %%
pdf("../../results/fig/fig8.pdf", width = 6, height = 7)


plot_grid(
      plot_grid(p1, p2, nrow = 1, ncol = 2,labels=c(LETTERS[1:2])),
    plot_grid(NULL, p3, NULL, nrow = 1, rel_widths = c(0.3, 1, 0.3)),
  plot_grid(p4, p5, nrow = 1, ncol = 2,labels=c(LETTERS[3:4])),
  nrow = 3, rel_heights = c(1,0.5,1)
)

dev.off()
# Out:
# png
#   2

# %% [markdown]
# fig 9

# %%
p1 <- image_read_pdf("../../results/fig/perez_GMMpca_sqrt_revise.pdf")
p2 <- image_read_pdf("../../results/fig/perez_legend.pdf")
p3 <- image_read_pdf("../../results/fig/perez_GMMhar_sqrt.pdf")
p4 <- image_read_pdf("../../results/fig/perez_ans.pdf")
p5 <- image_read_pdf("../../results/fig/perez_ss.pdf")
p1 <- as.grob(p1)
p2 <- as.grob(p2)
p3 <- as.grob(p3)
p4 <- as.grob(p4)
p5 <- as.grob(p5)

# %%
plot_grid(
      plot_grid(p1, p2, p3, nrow = 1, ncol = 3,labels=c(LETTERS[1], "", LETTERS[2]), rel_widths = c(3,1,3)),
  plot_grid(p4, p5, nrow = 1, ncol = 2,labels=c(LETTERS[3:4])),
  nrow = 2, rel_heights = c(1,0.5,1)
)
# Out:
# plot without title

# %%
pdf("../../results/fig/fig9.pdf", width = 6, height = 5.5)



plot_grid(
      plot_grid(p1, p2, p3, nrow = 1, ncol = 3,labels=c(LETTERS[1], "", LETTERS[2]), rel_widths = c(3,1,3)),
  plot_grid(p4, p5, nrow = 1, ncol = 2,labels=c(LETTERS[3:4])),
  nrow = 2
)

dev.off()
# Out:
# png
#   2

# %% [markdown]
# Sup 1

# %%
p1 <- image_read_pdf("../../results/fig_revise/image/supplement/offvar.pdf")
p2 <- image_read_pdf("../../results/fig_revise/image/supplement/baseline_sigma.pdf")
p3 <- image_read_pdf("../../results/fig_revise/image/supplement/more_s.pdf")
p1 <- as.grob(p1)
p2 <- as.grob(p2)
p3 <- as.grob(p3)

# %%
plot_grid(
  plot_grid(p1, p2, nrow = 1, ncol = 2,labels=c(LETTERS[1:2])),
    plot_grid(NULL, p3, NULL, nrow = 1, rel_widths = c(0.3, 1, 0.3), labels = LETTERS[3]),
  nrow = 2
)
# Out:
# plot without title

# %%
pdf("../../results/fig_revise/sup1.pdf", width = 6, height = 5)

plot_grid(
  plot_grid(p1, p2, nrow = 1, ncol = 2,labels=c(LETTERS[1:2])),
    plot_grid(NULL, p3, NULL, nrow = 1, rel_widths = c(0.3, 1, 0.3), labels = LETTERS[3]),
  nrow = 2
)
dev.off()
# Out:
# png
#   2

# %% [markdown]
# sup 7

# %%
p1 <- image_read_pdf("../../results/fig_revise/image/supplement/boxplot_cluster_gmmpca.pdf")
p2 <- image_read_pdf("../../results/fig_revise/image/supplement/boxplot_cluster_gmmscvi.pdf")
p3 <- image_read_pdf("../../results/fig_revise/image/supplement/boxplot_cluster_knnpca.pdf")
p4 <- image_read_pdf("../../results/fig_revise/image/supplement/boxplot_cluster_knnscvi.pdf")
p1 <- as.grob(p1)
p2 <- as.grob(p2)
p3 <- as.grob(p3)
p4 <- as.grob(p4)

# %%
pdf("../../results/fig_revise/sup7.pdf", width = 6, height = 5.5)

plot_grid(p1,p2,p3,p4,ncol = 2, labels=c(LETTERS[1:4]))

dev.off()
# Out:
# png
#   2

# %% [markdown]
# sup 8

# %%
p1 <- image_read_pdf("../../results/fig_revise/image/supplement/boxplot_lfcpde_gmmpca.pdf")
p2 <- image_read_pdf("../../results/fig_revise/image/supplement/boxplot_lfcpde_gmmscvi.pdf")
p3 <- image_read_pdf("../../results/fig_revise/image/supplement/boxplot_lfcpde_knnpca.pdf")
p4 <- image_read_pdf("../../results/fig_revise/image/supplement/boxplot_lfcpde_knnscvi.pdf")
p1 <- as.grob(p1)
p2 <- as.grob(p2)
p3 <- as.grob(p3)
p4 <- as.grob(p4)

# %%
pdf("../../results/fig_revise/sup8.pdf", width = 6, height = 5.5)

plot_grid(p1,p2,p3,p4,ncol = 2, labels=c(LETTERS[1:4]))

dev.off()
# Out:
# png
#   2

# %% [markdown]
# Sup 9

# %%
p1 <- image_read_pdf("../../results/fig_revise/image/supplement/boxplot_sd_w_gmmpca.pdf")
p2 <- image_read_pdf("../../results/fig_revise/image/supplement/boxplot_sd_w_gmmscvi.pdf")
p3 <- image_read_pdf("../../results/fig_revise/image/supplement/boxplot_sd_w_knnpca.pdf")
p4 <- image_read_pdf("../../results/fig_revise/image/supplement/boxplot_sd_w_knnscvi.pdf")
p1 <- as.grob(p1)
p2 <- as.grob(p2)
p3 <- as.grob(p3)
p4 <- as.grob(p4)

# %%
pdf("../../results/fig_revise/sup9.pdf", width = 6, height = 5.5)

plot_grid(p1,p2,p3,p4,ncol = 2, labels=c(LETTERS[1:4]))

dev.off()
# Out:
# png
#   2

# %% [markdown]
# sup 10

# %%
p1 <- image_read_pdf("../../results/fig_revise/image/supplement/boxplot_sd_w_gmmpca.pdf")
p2 <- image_read_pdf("../../results/fig_revise/image/supplement/boxplot_sd_w_gmmscvi.pdf")
p3 <- image_read_pdf("../../results/fig_revise/image/supplement/boxplot_sd_w_knnpca.pdf")
p4 <- image_read_pdf("../../results/fig_revise/image/supplement/boxplot_sd_w_knnscvi.pdf")
p1 <- as.grob(p1)
p2 <- as.grob(p2)
p3 <- as.grob(p3)
p4 <- as.grob(p4)

# %%
pdf("../../results/fig_revise/sup10.pdf", width = 6, height = 5.5)

plot_grid(p1,p2,p3,p4,ncol = 2, labels=c(LETTERS[1:4]))

dev.off()

# %% [markdown]
# sup 13

# %%
p1 <- image_read_pdf("../../results/fig_revise/covid_pseu.pdf")
p2 <- image_read_pdf("../../results/fig_revise/image/fig/covid143_legend.pdf")
p3 <- image_read_pdf("../../results/fig_revise/covid_pseu_sub.pdf")
p4 <- image_read_pdf("../../results/fig_revise/perez_pseu.pdf")
p1 <- as.grob(p1)
p2 <- as.grob(p2)
p3 <- as.grob(p3)
p4 <- as.grob(p4)

# %%
plot_grid(
  plot_grid(p1, p2, p3,nrow = 1, ncol =3,labels=c(LETTERS[1], "", LETTERS[2]), rel_widths = c(1,0.4,1)),
    plot_grid(NULL, p4, NULL, nrow = 1, rel_widths = c(0.3, 0.8, 0.3), labels = LETTERS[3]),
  nrow = 2
)
# Out:
# plot without title

# %%
pdf("../../results/fig_revise/pseudobulk.pdf", width = 6, height = 5)
plot_grid(
  plot_grid(p1, p2, p3,nrow = 1, ncol =3,labels=c(LETTERS[1], "", LETTERS[2]), rel_widths = c(1,0.4,1)),
    plot_grid(NULL, p4, NULL, nrow = 1, rel_widths = c(0.3, 0.8, 0.3), labels = LETTERS[3]),
  nrow = 2
)

dev.off()
# Out:
# png
#   2

# %%
p1 <- image_read_pdf("../../results/fig_revise/covid_mofa.pdf")
p2 <- image_read_pdf("../../results/fig_revise/image/fig/covid143_legend.pdf")
p3 <- image_read_pdf("../../results/fig_revise/covid_mofa_sub.pdf")
p4 <- image_read_pdf("../../results/fig_revise/perez_mofa.pdf")
p1 <- as.grob(p1)
p2 <- as.grob(p2)
p3 <- as.grob(p3)
p4 <- as.grob(p4)

# %%
pdf("../../results/fig_revise/mofa_vis.pdf", width = 6, height = 5)
plot_grid(
  plot_grid(p1, p2, p3,nrow = 1, ncol =3,labels=c(LETTERS[1], "", LETTERS[2]), rel_widths = c(1,0.4,1)),
    plot_grid(NULL, p4, NULL, nrow = 1, rel_widths = c(0.3, 0.8, 0.3), labels = LETTERS[3]),
  nrow = 2
)

dev.off()
# Out:
# png
#   2

# %% [markdown]
# sup 15

# %%
p1 <- image_read_pdf("../../results/fig_revise/image/supplement/svsc_original.pdf")
p2 <- image_read_pdf("../../results/fig_revise/image/supplement/sim_cluster_legend.pdf")
p3 <- image_read_pdf("../../results/fig_revise/image/supplement/sd013_lfc005_umap.pdf")
p1 <- as.grob(p1)
p2 <- as.grob(p2)
p3 <- as.grob(p3)

# %%
pdf("../../results/fig_revise/sup15.pdf", width = 6, height = 3)

plot_grid(p1,p2,p3,ncol = 3, labels=c(LETTERS[1],"", LETTERS[2]), rel_widths = c(4,1,4))

dev.off()
# Out:
# png
#   2

# %% [markdown]
# sup 16

# %%
p1 <- image_read_pdf("../../results/fig_revise/image/supplement/sd013_lfc005_umap.pdf")
p2 <- image_read_pdf("../../results/fig_revise/image/supplement/sim_cluster_legend.pdf")
p3 <- image_read_pdf("../../results/fig_revise/image/supplement/sd03_lfc005_umap.pdf")
p4 <- image_read_pdf("../../results/fig_revise/image/supplement/lfc005_umap.pdf")
p5 <- image_read_pdf("../../results/fig_revise/image/supplement/sim_group_legend.pdf")
p6 <- image_read_pdf("../../results/fig_revise/image/supplement/lfc015_umap.pdf")
p1 <- as.grob(p1)
p2 <- as.grob(p2)
p3 <- as.grob(p3)
p4 <- as.grob(p4)
p5 <- as.grob(p5)
p6 <- as.grob(p6)

# %%
pdf("../../results/fig_revise/sup16.pdf", width = 6, height = 4.5)

plot_grid(p1,p2,p3,p4,p5,p6,ncol = 3, labels=c(LETTERS[1],"", LETTERS[2],LETTERS[3],"", LETTERS[4]), rel_widths = c(4,1,4))

dev.off()
# Out:
# png
#   2

# %% [markdown]
# fabre liver comb

# %%
p1 <- image_read_pdf("../../results/fig_revise/fabreliver_GMMpca_sqrt.pdf")
p2 <- image_read_pdf("../../results/fig_revise/fabreliver_legend_update.pdf")
p3 <- image_read_pdf("../../results/fig_revise/fabre_ans_comb.pdf")


p1 <- as.grob(p1)
p2 <- as.grob(p2)
p3 <- as.grob(p3)

# %%
plot_grid(p1,p2,p3,ncol = 3, labels=c(LETTERS[1],"", LETTERS[2]), rel_widths = c(1.2,0.7,1.3))
# Out:
# plot without title

# %%
pdf("../../results/fig_revise/supfabreliver.pdf", width = 6, height = 3)

plot_grid(p1,p2,p3,ncol = 3, labels=c(LETTERS[1],"", LETTERS[2]), rel_widths = c(1.2,0.7,1.2))

dev.off()
# Out:
# png
#   2

# %% [markdown]
# compare covid with pilot, pseudobulk

# %%
p1 <- image_read_pdf("../../results/fig_revise/COVID143_methodcompare.pdf")
p2 <- image_read_pdf("../../results/fig_revise/COVID143_methodcompare_ss.pdf")

p1 <- as.grob(p1)
p2 <- as.grob(p2)

# %%
pdf("../../results/fig_revise/COVID143_compareresults.pdf", width = 6, height = 3)

plot_grid(p1,p2,ncol = 2, labels=c(LETTERS[1], LETTERS[2]))

dev.off()
# Out:
# png
#   2

# %%
p1 <- image_read_pdf("../../results/fig_revise/perez_methodcompare.pdf")
p2 <- image_read_pdf("../../results/fig_revise/perez_methodcompare_ss.pdf")

p1 <- as.grob(p1)
p2 <- as.grob(p2)

# %%
pdf("../../results/fig_revise/Perez2022_compareresults.pdf", width = 6, height = 2.5)

plot_grid(p1,p2,ncol = 2, labels=c(LETTERS[1], LETTERS[2]), rel_widths = c(0.8,0.8))

dev.off()
# Out:
# png
#   2
